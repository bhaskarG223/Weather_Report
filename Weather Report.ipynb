# %% [markdown]
# Weather Report Data

# %% [markdown]
# Here,Weather dataset is a time-series data set with per hour information about the weather condition at a particular location.it records temperature,
# Dew point Temperature,Relative humidity,Wind Speed,Pressure and Condition.

# %%
import pandas as pd

# %%
weather = pd.read_csv(r"C:\Users\bhanu\OneDrive\Desktop\Datasets for Pandas Projects_ Data Science\DataSets\Weather_report.csv")

# %%
weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#summary statistics for numerical columns

# %%
 weather.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# convert date/time to datetime format for easiar analysis

# %%
weather['Date/Time']=pd.to_datetime(weather['Date/Time'])

# %%
weather
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# 1. Add Month and Season columns for grouping

# %%
weather['Month'] = weather['Date/Time'].dt.month
weather['Season'] = weather['Month'] % 12 // 3 + 1
weather['Season'] = weather['Season'].replace({1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'})

# %%
weather.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  Month  Season
# 0            8.0     101.24                   Fog      1  Winter
# 1            8.0     101.24                   Fog      1  Winter
# 2            4.0     101.26  Freezing Drizzle,Fog      1  Winter
# 3            4.0     101.27  Freezing Drizzle,Fog      1  Winter
# 4            4.8     101.23                   Fog      1  Winter

# %% [markdown]
# 2.Extreme Events: Highest/Lowest Temperature

# %%
extreme_events = weather[['Temp_C', 'Date/Time']].sort_values(by='Temp_C', ascending=False)
highest_temp = extreme_events.head(1)
lowest_temp = extreme_events.tail(1)

# %%
weather.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  Month  Season
# 0            8.0     101.24                   Fog      1  Winter
# 1            8.0     101.24                   Fog      1  Winter
# 2            4.0     101.26  Freezing Drizzle,Fog      1  Winter
# 3            4.0     101.27  Freezing Drizzle,Fog      1  Winter
# 4            4.8     101.23                   Fog      1  Winter

# %% [markdown]
# 3. Grouping: Average stats by month

# %%
weather.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  Month  Season
# 0            8.0     101.24                   Fog      1  Winter
# 1            8.0     101.24                   Fog      1  Winter
# 2            4.0     101.26  Freezing Drizzle,Fog      1  Winter
# 3            4.0     101.27  Freezing Drizzle,Fog      1  Winter
# 4            4.8     101.23                   Fog      1  Winter

# %% [markdown]
# 4. Weather Patterns: Frequency of specific weather conditions

# %%
weather_frequency = weather['Weather'].value_counts()

# %%
weather.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  Month  Season
# 0            8.0     101.24                   Fog      1  Winter
# 1            8.0     101.24                   Fog      1  Winter
# 2            4.0     101.26  Freezing Drizzle,Fog      1  Winter
# 3            4.0     101.27  Freezing Drizzle,Fog      1  Winter
# 4            4.8     101.23                   Fog      1  Winter

# %% [markdown]
# #Display analysis results

# %%
highest_temp, lowest_temp, weather_frequency.head()
# Out:
# (      Temp_C           Date/Time
#  4695    33.0 2012-07-14 15:00:00,
#       Temp_C           Date/Time
#  344   -23.3 2012-01-15 08:00:00,
#  Weather
#  Mainly Clear     2106
#  Mostly Cloudy    2069
#  Cloudy           1728
#  Clear            1326
#  Snow              390
#  Name: count, dtype: int64)

# %%
import matplotlib.pyplot as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(weather.isnull())
plt.show()

# %% [markdown]
#  5. Trend Analysis: Temperature over time

# %%
plt.figure(figsize=(12, 6))
plt.plot(weather['Date/Time'], weather['Temp_C'], label='Temperature (°C)', color='blue', alpha=0.6)
plt.title('Temperature Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #display the analysis

# %%
weather.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  Month  Season
# 0            8.0     101.24                   Fog      1  Winter
# 1            8.0     101.24                   Fog      1  Winter
# 2            4.0     101.26  Freezing Drizzle,Fog      1  Winter
# 3            4.0     101.27  Freezing Drizzle,Fog      1  Winter
# 4            4.8     101.23                   Fog      1  Winter
